# %% [markdown]
# # Emotion Analysis for Screenplays

# %%
import os

# %%
def parse():
    #for root, dirs, files in os.walk('imsdb'):
        #for file in files:
         #   file = root + "/" + file
    sentences = []
    curr_string = ""
    file = "imsdb/Action/15minutes.txt"
    with open(file, 'r') as f:
        for line in f:
            line = line.strip()
            if len(line) > 1:
                sentence_parts = line.split(".")
                sentence_parts = [x for x in sentence_parts if x]
                print("\n\n\nSentence parts: ", sentence_parts)
                print("curr_string before appending: " + curr_string)
                curr_string += sentence_parts[0]
                print("curr_string after appending: " + curr_string)
                if len(sentence_parts) > 1:
                    sentences.append(curr_string)
                for i in range(1, len(sentence_parts)-1):
                    curr_string = sentence_parts[i]
                    sentences.append(curr_string)    
                if line.endswith("."):
                    sentences.append(curr_string)
                    curr_string = ""
                else:
                    curr_string += " " + sentence_parts[-1] + " "
                #print(curr_string)
        print(sentences)
                    
                    
                    
                    #treat special cases: Dr. etc, also INT./EXT.
                    #add punctuation too not just periods
                    #delete screenplay format stuff

# %%
parse()
# Out:
# Sentence parts:  ['<b><!--']
# curr_string before appending:
# curr_string after appending: <b><!--
#
#
#
# Sentence parts:  ['</b>if (window!= top)']
# curr_string before appending: <b><!-- <b><!--
# curr_string after appending: <b><!-- <b><!-- </b>if (window!= top)
#
#
#
# Sentence parts:  ['top', 'location', 'href=location', 'href']
# curr_string before appending: <b><!-- <b><!-- </b>if (window!= top) </b>if (window!= top)
# curr_string after appending: <b><!-- <b><!-- </b>if (window!= top) </b>if (window!= top) top
#
#
#
# Sentence parts:  ['<b>// -->']
# curr_string before appending: href=location href
# curr_string after appending: href=location href <b>// -->
#
#
#
# Sentence parts:  ['</b>']
# curr_string before appending: href=location href <b>// --> <b>// -->
# curr_string after appending: href=location href <b>// --> <b>// --> </b>
#
#
#
# Sentence parts:  ['15 Minutes']
# curr_string before appending: href=location href <b>// --> <b>// --> </b> </b>
# curr_string after appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes
#
#
#
# Sentence parts:  ['FADE IN']
# curr_string before appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes
# curr_string after appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN
#
#
#
# Sentence parts:  ['on the words CZECH AIRLINE', '  We are panning across the words']
# curr_string before appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN FADE IN
# curr_string after appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN FADE IN on the words CZECH AIRLINE
#
#
#
# Sentence parts:  ['on the side of the plane']
# curr_string before appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN FADE IN on the words CZECH AIRLINE   We are panning across the words
# curr_string after appending: href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN FADE IN on the words CZECH AIRLINE   We are panning across the words on the side of the plane
#
#
#
# Sentence parts:  ['INT', ' AIRPLANE']
# curr_string before appending:
# curr_string after appending: INT
#
#
#
# Sentence parts:  ['ANGLE DOWN']
# curr_string before appending: INT  AIRPLANE
# curr_string after appending: INT  AIRPLANE ANGLE DOWN
#
#
#
# Sentence parts:  ['on a tray table', '  Crumpled Czech bills and coins are on it']
# curr_string before appending: INT  AIRPLANE ANGLE DOWN ANGLE DOWN
# curr_string after appending: INT  AIRPLANE ANGLE DOWN ANGLE DOWN on a tray table
#
#
#
# Sentence parts:  ['Hands are counting the money', '  The airline hostess announces']
# curr_string before appending:
# curr_string after appending: Hands are counting the money
#
#
#
# Sentence parts:  ['the arrival at JFK - in CZECH', '  A hand reaches into a breast']
# curr_string before appending: Hands are counting the money   The airline hostess announces
# curr_string after appending: Hands are counting the money   The airline hostess announces the arrival at JFK - in CZECH
#
#
#
# Sentence parts:  ['pocket - pulling out two passports', '  One is opened', '  Belongs']
# curr_string before appending: Hands are counting the money   The airline hostess announces the arrival at JFK - in CZECH   A hand reaches into a breast
# curr_string after appending: Hands are counting the money   The airline hostess announces the arrival at JFK - in CZECH   A hand reaches into a breast pocket - pulling out two passports
#
#
#
# Sentence parts:  ['to EMIL SLOVAK', '  The next passport belongs to OLEG RAZGUL']
# curr_string before appending:   One is opened   Belongs
# curr_string after appending:   One is opened   Belongs to EMIL SLOVAK
#
#
#
# Sentence parts:  ['The hand passes the Oleg Razgul passport to the man next to']
# curr_string before appending:
# curr_string after appending: The hand passes the Oleg Razgul passport to the man next to
#
#
#
# Sentence parts:  ['him', '  We notice several empty airline bottles of vodka and a']
# curr_string before appending: The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to
# curr_string after appending: The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him
#
#
#
# Sentence parts:  ["small disposable camera on Oleg's tray table", '  The passport']
# curr_string before appending: The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him   We notice several empty airline bottles of vodka and a
# curr_string after appending: The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him   We notice several empty airline bottles of vodka and a small disposable camera on Oleg's tray table
#
#
#
# Sentence parts:  ['is set down', '  Oleg picks it up', "  We hear Emil's voice in"]
# curr_string before appending: The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him   We notice several empty airline bottles of vodka and a small disposable camera on Oleg's tray table   The passport
# curr_string after appending: The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him   We notice several empty airline bottles of vodka and a small disposable camera on Oleg's tray table   The passport is set down
#
#
#
# Sentence parts:  ['CZECH', '  The scene is subtitled in ENGLISH']
# curr_string before appending:   Oleg picks it up   We hear Emil's voice in
# curr_string after appending:   Oleg picks it up   We hear Emil's voice in CZECH
#
#
#
# Sentence parts:  ['EMIL (V', 'O', ')']
# curr_string before appending:
# curr_string after appending: EMIL (V
#
#
#
# Sentence parts:  ['Just do what I do', '  Say the same thing I']
# curr_string before appending: O )
# curr_string after appending: O ) Just do what I do
#
#
#
# Sentence parts:  ['say', "  Don't open your mouth"]
# curr_string before appending: O ) Just do what I do   Say the same thing I
# curr_string after appending: O ) Just do what I do   Say the same thing I say
#
#
#
# Sentence parts:  ['OLEG (V', 'O', ')']
# curr_string before appending:
# curr_string after appending: OLEG (V
#
#
#
# Sentence parts:  ['Okay']
# curr_string before appending: O )
# curr_string after appending: O ) Okay
#
#
#
# Sentence parts:  ['INT', ' PASSPORT CONTROL - KENNEDY AIRPORT - DAY']
# curr_string before appending:
# curr_string after appending: INT
#
#
#
# Sentence parts:  ['CAMERA DOLLIES down a long line of passengers', '  They are']
# curr_string before appending: INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY
# curr_string after appending: INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers
#
#
#
# Sentence parts:  ['split into two lines - one for Americans, the other for']
# curr_string before appending: INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers   They are
# curr_string after appending: INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers   They are split into two lines - one for Americans, the other for
#
#
#
# Sentence parts:  ['visitors', '  CAMERA finally arrives at EMIL SLOVAK', '  An']
# curr_string before appending: INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers   They are split into two lines - one for Americans, the other for split into two lines - one for Americans, the other for
# curr_string after appending: INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers   They are split into two lines - one for Americans, the other for split into two lines - one for Americans, the other for visitors
#
#
#
# Sentence parts:  ["unshaven Czech in his mid-30's", '  Tall, scraggly beard']
# curr_string before appending:   CAMERA finally arrives at EMIL SLOVAK   An
# curr_string after appending:   CAMERA finally arrives at EMIL SLOVAK   An unshaven Czech in his mid-30's
#
#
#
# Sentence parts:  ['Piercing blue eyes', "  He's dressed in an outdated suit", '  His']
# curr_string before appending:
# curr_string after appending: Piercing blue eyes
#
#
#
# Sentence parts:  ['eyes are alert, cunning and smart']
# curr_string before appending:   He's dressed in an outdated suit   His
# curr_string after appending:   He's dressed in an outdated suit   His eyes are alert, cunning and smart
#
#
#
# Sentence parts:  ['OLEG RAZGUL, stands in line behind Emil', '  Oleg is big', '  Not']
# curr_string before appending:
# curr_string after appending: OLEG RAZGUL, stands in line behind Emil
#
#
#
# Sentence parts:  ['tall - but wide', "  A wrestler's body", '  Emil looks at Oleg']
# curr_string before appending:   Oleg is big   Not
# curr_string after appending:   Oleg is big   Not tall - but wide
#
#
#
# Sentence parts:  ['(The following is in CZECH and subtitled in ENGLISH', ')']
# curr_string before appending:
# curr_string after appending: (The following is in CZECH and subtitled in ENGLISH
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: (The following is in CZECH and subtitled in ENGLISH )
# curr_string after appending: (The following is in CZECH and subtitled in ENGLISH ) EMIL
#
#
#
# Sentence parts:  ["Don't fool around"]
# curr_string before appending: (The following is in CZECH and subtitled in ENGLISH ) EMIL EMIL
# curr_string after appending: (The following is in CZECH and subtitled in ENGLISH ) EMIL EMIL Don't fool around
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending:
# curr_string after appending: OLEG
#
#
#
# Sentence parts:  ['Okay']
# curr_string before appending: OLEG OLEG
# curr_string after appending: OLEG OLEG Okay
#
#
#
# Sentence parts:  ['Oleg holds up his disposable camera - at arms length - to']
# curr_string before appending:
# curr_string after appending: Oleg holds up his disposable camera - at arms length - to
#
#
#
# Sentence parts:  ['take a picture of himself']
# curr_string before appending: Oleg holds up his disposable camera - at arms length - to Oleg holds up his disposable camera - at arms length - to
# curr_string after appending: Oleg holds up his disposable camera - at arms length - to Oleg holds up his disposable camera - at arms length - to take a picture of himself
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending:
# curr_string after appending: EMIL
#
#
#
# Sentence parts:  ['Did you hear what I said?']
# curr_string before appending: EMIL EMIL
# curr_string after appending: EMIL EMIL Did you hear what I said?
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending: EMIL EMIL Did you hear what I said? Did you hear what I said?
# curr_string after appending: EMIL EMIL Did you hear what I said? Did you hear what I said? OLEG
#
#
#
# Sentence parts:  ['I want to document my trip to America']
# curr_string before appending: EMIL EMIL Did you hear what I said? Did you hear what I said? OLEG OLEG
# curr_string after appending: EMIL EMIL Did you hear what I said? Did you hear what I said? OLEG OLEG I want to document my trip to America
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['Next']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Next
#
#
#
# Sentence parts:  ['(Emil steps up)']
# curr_string before appending:
# curr_string after appending: (Emil steps up)
#
#
#
# Sentence parts:  ['Could I see your documents, please?']
# curr_string before appending: (Emil steps up) (Emil steps up)
# curr_string after appending: (Emil steps up) (Emil steps up) Could I see your documents, please?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: (Emil steps up) (Emil steps up) Could I see your documents, please? Could I see your documents, please?
# curr_string after appending: (Emil steps up) (Emil steps up) Could I see your documents, please? Could I see your documents, please? EMIL
#
#
#
# Sentence parts:  ['Yes sir']
# curr_string before appending: (Emil steps up) (Emil steps up) Could I see your documents, please? Could I see your documents, please? EMIL EMIL
# curr_string after appending: (Emil steps up) (Emil steps up) Could I see your documents, please? Could I see your documents, please? EMIL EMIL Yes sir
#
#
#
# Sentence parts:  ['He hands the passport to the officer who runs it through an']
# curr_string before appending:
# curr_string after appending: He hands the passport to the officer who runs it through an
#
#
#
# Sentence parts:  ['image swipe', '  Emil glances furtively back to Oleg']
# curr_string before appending: He hands the passport to the officer who runs it through an He hands the passport to the officer who runs it through an
# curr_string after appending: He hands the passport to the officer who runs it through an He hands the passport to the officer who runs it through an image swipe
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['What is your intended purpose of your']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your
#
#
#
# Sentence parts:  ['visit to the United States?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your visit to the United States?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your visit to the United States? visit to the United States?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your visit to the United States? visit to the United States? EMIL
#
#
#
# Sentence parts:  ['Two weeks holiday']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your visit to the United States? visit to the United States? EMIL EMIL
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your visit to the United States? visit to the United States? EMIL EMIL Two weeks holiday
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['How much money are you carrying with']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with
#
#
#
# Sentence parts:  ['you?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with you?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with you? you?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with you? you? EMIL
#
#
#
# Sentence parts:  ['I have five-hundred dollars']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with you? you? EMIL EMIL
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with you? you? EMIL EMIL I have five-hundred dollars
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['Can you show me?  Sir, no cameras in the']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the
#
#
#
# Sentence parts:  ['FIS area!']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the FIS area!
#
#
#
# Sentence parts:  ['Oleg was about to take a picture of Emil and the Immigration']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the FIS area! FIS area!
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the FIS area! FIS area! Oleg was about to take a picture of Emil and the Immigration
#
#
#
# Sentence parts:  ['Officer', '  Oleg puts the camera away', '  Smiles sheepishly']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the FIS area! FIS area! Oleg was about to take a picture of Emil and the Immigration Oleg was about to take a picture of Emil and the Immigration
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the FIS area! FIS area! Oleg was about to take a picture of Emil and the Immigration Oleg was about to take a picture of Emil and the Immigration Officer
#
#
#
# Sentence parts:  ["IMMIGRATION OFFICER (CONT'D)"]
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER (CONT'D)
#
#
#
# Sentence parts:  ['(to Emil)']
# curr_string before appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D)
# curr_string after appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil)
#
#
#
# Sentence parts:  ['Is he with you?  Are you travelling']
# curr_string before appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil)
# curr_string after appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling
#
#
#
# Sentence parts:  ['together?']
# curr_string before appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling Is he with you?  Are you travelling
# curr_string after appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling Is he with you?  Are you travelling together?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling Is he with you?  Are you travelling together? together?
# curr_string after appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling Is he with you?  Are you travelling together? together? EMIL
#
#
#
# Sentence parts:  ['Yes']
# curr_string before appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling Is he with you?  Are you travelling together? together? EMIL EMIL
# curr_string after appending: IMMIGRATION OFFICER (CONT'D) IMMIGRATION OFFICER (CONT'D) (to Emil) (to Emil) Is he with you?  Are you travelling Is he with you?  Are you travelling together? together? EMIL EMIL Yes
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['Please join us']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Please join us
#
#
#
# Sentence parts:  ['(to Oleg)']
# curr_string before appending:
# curr_string after appending: (to Oleg)
#
#
#
# Sentence parts:  ['Come on forward']
# curr_string before appending: (to Oleg) (to Oleg)
# curr_string after appending: (to Oleg) (to Oleg) Come on forward
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending:
# curr_string after appending: EMIL
#
#
#
# Sentence parts:  ['Is there a problem?']
# curr_string before appending: EMIL EMIL
# curr_string after appending: EMIL EMIL Is there a problem?
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem?
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ["No, you're travelling together", '  I want']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together
#
#
#
# Sentence parts:  ['to talk to you together', '  Hi, how are']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together
#
#
#
# Sentence parts:  ['you?  Can I take a look at your']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your
#
#
#
# Sentence parts:  ['documents?']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents?
#
#
#
# Sentence parts:  ["(takes Oleg's passport)"]
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents?
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport)
#
#
#
# Sentence parts:  ['Are you related?']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport) (takes Oleg's passport)
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport) (takes Oleg's passport) Are you related?
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport) (takes Oleg's passport) Are you related? Are you related?
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport) (takes Oleg's passport) Are you related? Are you related? OLEG
#
#
#
# Sentence parts:  ['Yes', "he's my friend"]
# curr_string before appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport) (takes Oleg's passport) Are you related? Are you related? OLEG OLEG
# curr_string after appending: EMIL EMIL Is there a problem? Is there a problem? IMMIGRATION OFFICER IMMIGRATION OFFICER No, you're travelling together   I want to talk to you together   Hi, how are you?  Can I take a look at your you?  Can I take a look at your documents? documents? (takes Oleg's passport) (takes Oleg's passport) Are you related? Are you related? OLEG OLEG Yes
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['Okay', "  You're a Czech national and"]
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay
#
#
#
# Sentence parts:  ["you're a Russian national", '  How do you']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay   You're a Czech national and
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay   You're a Czech national and you're a Russian national
#
#
#
# Sentence parts:  ['know one another?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay   You're a Czech national and you're a Russian national   How do you
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay   You're a Czech national and you're a Russian national   How do you know one another?
#
#
#
# Sentence parts:  ['Oleg starts to speak, but Emil cuts him off']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay   You're a Czech national and you're a Russian national   How do you know one another? know one another?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Okay   You're a Czech national and you're a Russian national   How do you know one another? know one another? Oleg starts to speak, but Emil cuts him off
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending:
# curr_string after appending: EMIL
#
#
#
# Sentence parts:  ['We are both from Prague']
# curr_string before appending: EMIL EMIL
# curr_string after appending: EMIL EMIL We are both from Prague
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['(to Oleg)']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg)
#
#
#
# Sentence parts:  ['How long are you planning to stay?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg)
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) How long are you planning to stay?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) How long are you planning to stay? How long are you planning to stay?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) How long are you planning to stay? How long are you planning to stay? EMIL
#
#
#
# Sentence parts:  ['Two weeks']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) How long are you planning to stay? How long are you planning to stay? EMIL EMIL
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) How long are you planning to stay? How long are you planning to stay? EMIL EMIL Two weeks
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ["I'd like to speak for himself, okay?"]
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER I'd like to speak for himself, okay?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER I'd like to speak for himself, okay? I'd like to speak for himself, okay?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER I'd like to speak for himself, okay? I'd like to speak for himself, okay? EMIL
#
#
#
# Sentence parts:  ["He doesn't speak English"]
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER I'd like to speak for himself, okay? I'd like to speak for himself, okay? EMIL EMIL
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER I'd like to speak for himself, okay? I'd like to speak for himself, okay? EMIL EMIL He doesn't speak English
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending:
# curr_string after appending: OLEG
#
#
#
# Sentence parts:  ['I speak English']
# curr_string before appending: OLEG OLEG
# curr_string after appending: OLEG OLEG I speak English
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['(to Oleg)']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg)
#
#
#
# Sentence parts:  ['Then answer my questions', '  Where were']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg)
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions
#
#
#
# Sentence parts:  ['you planning to stay during the two']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two
#
#
#
# Sentence parts:  ["weeks that you're here?"]
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two you planning to stay during the two
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two you planning to stay during the two weeks that you're here?
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two you planning to stay during the two weeks that you're here? weeks that you're here?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two you planning to stay during the two weeks that you're here? weeks that you're here? OLEG
#
#
#
# Sentence parts:  ['New York']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two you planning to stay during the two weeks that you're here? weeks that you're here? OLEG OLEG
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER (to Oleg) (to Oleg) Then answer my questions   Where were you planning to stay during the two you planning to stay during the two weeks that you're here? weeks that you're here? OLEG OLEG New York
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ["Yes, we're in New York now", '  But where']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now
#
#
#
# Sentence parts:  ['are you planning to stay in New York?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now   But where
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now   But where are you planning to stay in New York?
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now   But where are you planning to stay in New York? are you planning to stay in New York?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now   But where are you planning to stay in New York? are you planning to stay in New York? OLEG
#
#
#
# Sentence parts:  ['A cheap hotel']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now   But where are you planning to stay in New York? are you planning to stay in New York? OLEG OLEG
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Yes, we're in New York now   But where are you planning to stay in New York? are you planning to stay in New York? OLEG OLEG A cheap hotel
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['What are you coming here to do?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What are you coming here to do?
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What are you coming here to do? What are you coming here to do?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What are you coming here to do? What are you coming here to do? OLEG
#
#
#
# Sentence parts:  ["I'm here for movies"]
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What are you coming here to do? What are you coming here to do? OLEG OLEG
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER What are you coming here to do? What are you coming here to do? OLEG OLEG I'm here for movies
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['Movies', 'to be in the movies or to see']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies
#
#
#
# Sentence parts:  ['movies?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies to be in the movies or to see
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies to be in the movies or to see movies?
#
#
#
# Sentence parts:  ['OLEG']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies to be in the movies or to see movies? movies?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies to be in the movies or to see movies? movies? OLEG
#
#
#
# Sentence parts:  ['Yes', '  No', '  Both', '  When I was a boy, I']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies to be in the movies or to see movies? movies? OLEG OLEG
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Movies to be in the movies or to see movies? movies? OLEG OLEG Yes
#
#
#
# Sentence parts:  ['see movie at school called "It\'s a']
# curr_string before appending:   Both   When I was a boy, I
# curr_string after appending:   Both   When I was a boy, I see movie at school called "It's a
#
#
#
# Sentence parts:  ['Wonderful Life" directed by Frank Capra']
# curr_string before appending:   Both   When I was a boy, I see movie at school called "It's a see movie at school called "It's a
# curr_string after appending:   Both   When I was a boy, I see movie at school called "It's a see movie at school called "It's a Wonderful Life" directed by Frank Capra
#
#
#
# Sentence parts:  ['Ever since I want to come to America']
# curr_string before appending:
# curr_string after appending: Ever since I want to come to America
#
#
#
# Sentence parts:  ['Land of the free', '  Home of the brave', '  A']
# curr_string before appending:
# curr_string after appending: Land of the free
#
#
#
# Sentence parts:  ['land where anyone can be anything', ' As']
# curr_string before appending:   Home of the brave   A
# curr_string after appending:   Home of the brave   A land where anyone can be anything
#
#
#
# Sentence parts:  ['long as they are white']
# curr_string before appending:   Home of the brave   A land where anyone can be anything  As
# curr_string after appending:   Home of the brave   A land where anyone can be anything  As long as they are white
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending:
# curr_string after appending: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ['Excuse me?']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me?
#
#
#
# Sentence parts:  ['EMIL']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me? Excuse me?
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me? Excuse me? EMIL
#
#
#
# Sentence parts:  ['He made joke, bad joke', '  First time on']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me? Excuse me? EMIL EMIL
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me? Excuse me? EMIL EMIL He made joke, bad joke
#
#
#
# Sentence parts:  ['airplane']
# curr_string before appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me? Excuse me? EMIL EMIL He made joke, bad joke   First time on
# curr_string after appending: IMMIGRATION OFFICER IMMIGRATION OFFICER Excuse me? Excuse me? EMIL EMIL He made joke, bad joke   First time on airplane
#
#
#
# Sentence parts:  ['The SUPERVISOR comes over to see what the problem is:']
# curr_string before appending:
# curr_string after appending: The SUPERVISOR comes over to see what the problem is:
#
#
#
# Sentence parts:  ['IMMIGRATION OFFICER']
# curr_string before appending: The SUPERVISOR comes over to see what the problem is: The SUPERVISOR comes over to see what the problem is:
# curr_string after appending: The SUPERVISOR comes over to see what the problem is: The SUPERVISOR comes over to see what the problem is: IMMIGRATION OFFICER
#
#
#
# Sentence parts:  ["Well, they've got valid visas, but they"]
# curr_string before appending: The SUPERVISOR comes over to see what the problem is: The SUPERVISOR comes over to see what the problem is: IMMIGRATION OFFICER IMMIGRATION OFFICER
# curr_string after appending: The SUPERVISOR comes over to see what the problem is: The SUPERVISOR comes over to see what the problem is: IMMIGRATION OFFICER IMMIGRATION OFFICER Well, they've got valid visas, but they
#
#
#
# Sentence parts:  ["don't have much money", '  Uh', " and I'm"]
# curr_string before appending: The SUPERVISOR comes over to see what the problem is: The SUPERVISOR comes over to see what the problem is: IMMIGRATION OFFICER IMMIGRATION OFFICER Well, they've got valid visas, but they Well, they've got valid visas, but they
# curr_string after appending: The SUPERVISOR comes over to see what the problem is: The SUPERVISOR comes over to see what the problem is: IMMIGRATION OFFICER IMMIGRATION OFFICER Well, they've got valid visas, but they Well, they've got valid visas, but they don't have much money
#
#
#
# Sentence parts:  ['not', "uh, I think there's a possibility"]
# curr_string before appending:   Uh  and I'm
# curr_string after appending:   Uh  and I'm not
#
#
#
# Sentence parts:  ['they may be coming to live and reside']
# curr_string before appending:   Uh  and I'm not uh, I think there's a possibility
# curr_string after appending:   Uh  and I'm not uh, I think there's a possibility they may be coming to live and reside
#
#
#
# Sentence parts:  ['SUPERVISOR']
# curr_string before appending:
# curr_string after appending: SUPERVISOR
#
#
#
# Sentence parts:  ['Look how long the line is', '  We gotta']
# curr_string before appending: SUPERVISOR SUPERVISOR
# curr_string after appending: SUPERVISOR SUPERVISOR Look how long the line is
#
#
#
# Sentence parts:  ["move 'em out", "  I'll take them down to"]
# curr_string before appending: SUPERVISOR SUPERVISOR Look how long the line is   We gotta
# curr_string after appending: SUPERVISOR SUPERVISOR Look how long the line is   We gotta move 'em out
#
#
#
# Sentence parts:  ['secondary']
# curr_string before appending: SUPERVISOR SUPERVISOR Look how long the line is   We gotta move 'em out   I'll take them down to
# curr_string after appending: SUPERVISOR SUPERVISOR Look how long the line is   We gotta move 'em out   I'll take them down to secondary
#
#
#
# Sentence parts:  ['Emil looks at Oleg, pissed']
# curr_string before appending:
# curr_string after appending: Emil looks at Oleg, pissed
#
#
#
# Sentence parts:  ['INT', ' P', 'B', " HERMAN'S RESTAURANT - DAY"]
# curr_string before appending:
# curr_string after appending: INT
#
#
#
# Sentence parts:  ['The place is empty except for one table at the end of the']
# curr_string before appending: B  HERMAN'S RESTAURANT - DAY
# curr_string after appending: B  HERMAN'S RESTAURANT - DAY The place is empty except for one table at the end of the
#
#
#
# Sentence parts:  ['bar', "  EDDIE FLEMMING, Manhattan's most famous detective, and"]
# curr_string before appending: B  HERMAN'S RESTAURANT - DAY The place is empty except for one table at the end of the The place is empty except for one table at the end of the
# curr_string after appending: B  HERMAN'S RESTAURANT - DAY The place is empty except for one table at the end of the The place is empty except for one table at the end of the bar
#
#
#
# Sentence parts:  ['his savvy, black partner, LEON JACKSON are having cocktails']
# curr_string before appending: B  HERMAN'S RESTAURANT - DAY The place is empty except for one table at the end of the The place is empty except for one table at the end of the bar   EDDIE FLEMMING, Manhattan's most famous detective, and
# curr_string after appending: B  HERMAN'S RESTAURANT - DAY The place is empty except for one table at the end of the The place is empty except for one table at the end of the bar   EDDIE FLEMMING, Manhattan's most famous detective, and his savvy, black partner, LEON JACKSON are having cocktails
#
#
#
# Sentence parts:  ['Eddie is smoothly handsome, tough, smart and tired', '  Not only']
# curr_string before appending:
# curr_string after appending: Eddie is smoothly handsome, tough, smart and tired
#
#
#
# Sentence parts:  ['is he the best homicide detective Manhattan has ever seen,']
# curr_string before appending: Eddie is smoothly handsome, tough, smart and tired   Not only
# curr_string after appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen,
#
#
#
# Sentence parts:  ["he's continually mentioned in New York columns and has been"]
# curr_string before appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen,
# curr_string after appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been
#
#
#
# Sentence parts:  ['the subject of several magazine articles', "  There's even been"]
# curr_string before appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been he's continually mentioned in New York columns and has been
# curr_string after appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been he's continually mentioned in New York columns and has been the subject of several magazine articles
#
#
#
# Sentence parts:  ['a TV movie about one of his biggest cases', '  Leon has been']
# curr_string before appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been he's continually mentioned in New York columns and has been the subject of several magazine articles   There's even been
# curr_string after appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been he's continually mentioned in New York columns and has been the subject of several magazine articles   There's even been a TV movie about one of his biggest cases
#
#
#
# Sentence parts:  ['with Eddie a long time and was also featured in the TV movie']
# curr_string before appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been he's continually mentioned in New York columns and has been the subject of several magazine articles   There's even been a TV movie about one of his biggest cases   Leon has been
# curr_string after appending: Eddie is smoothly handsome, tough, smart and tired   Not only is he the best homicide detective Manhattan has ever seen, is he the best homicide detective Manhattan has ever seen, he's continually mentioned in New York columns and has been he's continually mentioned in New York columns and has been the subject of several magazine articles   There's even been a TV movie about one of his biggest cases   Leon has been with Eddie a long time and was also featured in the TV movie
#
#
#
# Sentence parts:  ['Sitting with Eddie and Leon is ROBERT HAWKINS, host and star']
# curr_string before appending:
# curr_string after appending: Sitting with Eddie and Leon is ROBERT HAWKINS, host and star
#
#
#
# Sentence parts:  ['reporter for the tabloid show, "Top Story', '"  Hawkins is also']
# curr_string before appending: Sitting with Eddie and Leon is ROBERT HAWKINS, host and star Sitting with Eddie and Leon is ROBERT HAWKINS, host and star
# curr_string after appending: Sitting with Eddie and Leon is ROBERT HAWKINS, host and star Sitting with Eddie and Leon is ROBERT HAWKINS, host and star reporter for the tabloid show, "Top Story
#
#
#
# Sentence parts:  ['the best in the business and has dealt with them all: Joey']
# curr_string before appending: Sitting with Eddie and Leon is ROBERT HAWKINS, host and star Sitting with Eddie and Leon is ROBERT HAWKINS, host and star reporter for the tabloid show, "Top Story "  Hawkins is also
# ...
#
#
#
# Sentence parts:  ['problems', '  WB11 has also learned that']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems
#
#
#
# Sentence parts:  ['the fire Marshal has retained an']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an
#
#
#
# Sentence parts:  ['immigration lawyer to help Daphne']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne
#
#
#
# Sentence parts:  ['Handlova with her case', '  We wish her']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case
#
#
#
# Sentence parts:  ['well', '  This is Nicolette Karas, live at']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case   We wish her
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case   We wish her well
#
#
#
# Sentence parts:  ['Battery Park, WB11 New York', '  Good']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case   We wish her well   This is Nicolette Karas, live at
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case   We wish her well   This is Nicolette Karas, live at Battery Park, WB11 New York
#
#
#
# Sentence parts:  ['night']
# curr_string before appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case   We wish her well   This is Nicolette Karas, live at Battery Park, WB11 New York   Good
# curr_string after appending: The CAMERA PULLS BACK from Nicolette's face and the video is The CAMERA PULLS BACK from Nicolette's face and the video is now on: now on: THE JUMBOTRON IN TIMES SQUARE THE JUMBOTRON IN TIMES SQUARE We PULL BACK FURTHER and FURTHER   Nicolette finishing her stand up: stand up: NICOLETTE (CONT'D) NICOLETTE (CONT'D) New York City has a new hero, Fire New York City has a new hero, Fire Marshal Jordan Warsaw   I hope that Fire Marshal Warsaw's heroic actions this Marshal Warsaw's heroic actions this afternoon will help with his other legal afternoon will help with his other legal problems   WB11 has also learned that the fire Marshal has retained an the fire Marshal has retained an immigration lawyer to help Daphne immigration lawyer to help Daphne Handlova with her case   We wish her well   This is Nicolette Karas, live at Battery Park, WB11 New York   Good night
#
#
#
# Sentence parts:  ['THE SCREEN']
# curr_string before appending:
# curr_string after appending: THE SCREEN
#
#
#
# Sentence parts:  ['FADES TO BLACK']
# curr_string before appending: THE SCREEN THE SCREEN
# curr_string after appending: THE SCREEN THE SCREEN FADES TO BLACK
# ['<b><!-- <b><!-- </b>if (window!= top) </b>if (window!= top) top', 'location', 'href=location', 'href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN FADE IN on the words CZECH AIRLINE', 'href=location href <b>// --> <b>// --> </b> </b> 15 Minutes 15 Minutes FADE IN FADE IN on the words CZECH AIRLINE   We are panning across the words on the side of the plane', 'INT', 'INT  AIRPLANE ANGLE DOWN ANGLE DOWN on a tray table', 'INT  AIRPLANE ANGLE DOWN ANGLE DOWN on a tray table', 'Hands are counting the money', 'Hands are counting the money   The airline hostess announces the arrival at JFK - in CZECH', 'Hands are counting the money   The airline hostess announces the arrival at JFK - in CZECH   A hand reaches into a breast pocket - pulling out two passports', '  One is opened', '  One is opened   Belongs to EMIL SLOVAK', '  One is opened   Belongs to EMIL SLOVAK', 'The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him', "The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him   We notice several empty airline bottles of vodka and a small disposable camera on Oleg's tray table", "The hand passes the Oleg Razgul passport to the man next to The hand passes the Oleg Razgul passport to the man next to him   We notice several empty airline bottles of vodka and a small disposable camera on Oleg's tray table   The passport is set down", '  Oleg picks it up', "  Oleg picks it up   We hear Emil's voice in CZECH", "  Oleg picks it up   We hear Emil's voice in CZECH", 'EMIL (V', 'O', 'O ) Just do what I do', 'O ) Just do what I do   Say the same thing I say', 'O ) Just do what I do   Say the same thing I say', 'OLEG (V', 'O', 'O ) Okay', 'INT', 'INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers', 'INT  PASSPORT CONTROL - KENNEDY AIRPORT - DAY CAMERA DOLLIES down a long line of passengers   They are split into two lines - one for Americans, the other for split into two lines - one for Americans, the other for visitors', '  CAMERA finally arrives at EMIL SLOVAK', "  CAMERA finally arrives at EMIL SLOVAK   An unshaven Czech in his mid-30's", "  CAMERA finally arrives at EMIL SLOVAK   An unshaven Czech in his mid-30's", 'Piercing blue eyes', "  He's dressed in an outdated suit", "  He's dressed in an outdated suit   His eyes are alert, cunning and smart", 'OLEG RAZGUL, stands in line behind Emil', '  Oleg is big', '  Oleg is big   Not tall - but wide', "  A wrestler's body", "  A wrestler's body", '(The following is in CZECH and subtitled in ENGLISH', "(The following is in CZECH and subtitled in ENGLISH ) EMIL EMIL Don't fool around", 'OLEG OLEG Okay', 'Oleg holds up his disposable camera - at arms length - to Oleg holds up his disposable camera - at arms length - to take a picture of himself', 'EMIL EMIL Did you hear what I said? Did you hear what I said? OLEG OLEG I want to document my trip to America', 'IMMIGRATION OFFICER IMMIGRATION OFFICER Next', '(Emil steps up) (Emil steps up) Could I see your documents, please? Could I see your documents, please? EMIL EMIL Yes sir', 'He hands the passport to the officer who runs it through an He hands the passport to the officer who runs it through an image swipe', 'He hands the passport to the officer who runs it through an He hands the passport to the officer who runs it through an image swipe', 'IMMIGRATION OFFICER IMMIGRATION OFFICER What is your intended purpose of your What is your intended purpose of your visit to the United States? visit to the United States? EMIL EMIL Two weeks holiday', 'IMMIGRATION OFFICER IMMIGRATION OFFICER How much money are you carrying with How much money are you carrying with you? you? EMIL EMIL I have five-hundred dollars', 'IMMIGRATION OFFICER IMMIGRATION OFFICER Can you show me?  Sir, no cameras in the Can you show me?  Sir, no cameras in the FIS area! FIS area! Ol ...
